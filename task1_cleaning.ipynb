# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='magma')
plt.title("Where is data missing?")
plt.show()

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# drop Cabin only if it exists
if 'Cabin' in df.columns:
    df.drop(columns=['Cabin'], inplace=True)

df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
print("duplicate rows:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
print("after removing:", df.duplicated().sum())
# Out:
# duplicate rows: 0
# after removing: 0

# %%
df.dtypes
# Survived is 0/1 but it should be treated as category not integer
df['Survived'] = df['Survived'].astype('category')

# same for Pclass — 1, 2, 3 are classes not numbers
df['Pclass'] = df['Pclass'].astype('category')

df.dtypes
# Out:
# PassengerId       int64
# Survived       category
# Pclass         category
# Name                str
# Sex                 str
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket              str
# Fare            float64
# Embarked            str
# dtype: object

# %%
# some column names aren't very readable
df.rename(columns={
    'SibSp' : 'Siblings_Spouses',
    'Parch'  : 'Parents_Children',
    'Fare'   : 'Ticket_Fare'
}, inplace=True)

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'Siblings_Spouses', 'Parents_Children', 'Ticket', 'Ticket_Fare',
#        'Embarked'],
#       dtype='str')

# %%
df.shape
df.isnull().sum()
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    Siblings_Spouses  Parents_Children            Ticket  Ticket_Fare Embarked
# 0                 1                 0         A/5 21171       7.2500        S
# 1                 1                 0          PC 17599      71.2833        C
# 2                 0                 0  STON/O2. 3101282       7.9250        S
# ...

# %%
df.to_csv("titanic_cleaned.csv", index=False)
print("done, saved as titanic_cleaned.csv")
# Out:
# done, saved as titanic_cleaned.csv
